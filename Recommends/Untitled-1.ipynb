# %%
import pandas as pd

# %%
df = pd.read_csv("D:\senti_pro\ECommerce\\reviews.csv")

# %%
df
# Out:
#                                                review                  user  \
# 0   After using Samsung Galaxy S23 Ultra for quite...         Aditya Sharma
# 1   I'll keep it short and direct.-Great in hand f...  Prasada reddy padala
# 2   Very good smart phone with in budget Specially...         Aditya Sharma
# 3   Great camera, OS, build quality. Overall a gre...         Aditya Sharma
# 4   First of all, this was my last smartphone purc...         Sukoon Sharma
# ..                                                ...                   ...
# 95                                English (Automated)                   NaN
# 96                                            default                   NaN
# 97                                         , selected         zuhaib parvez
# 98                                         Fullscreen         Aditya Sharma
# 99  Already put my sim and writing review from thi...  Prasada reddy padala
#
#          verification        date  length
# ...
